# %% [markdown]
# #BERT Embedding + ClassifierDLApproach

# %%
# !pip install spark-nlp
# !pip install pyspark
# Out:
# Collecting spark-nlp
#   Downloading spark_nlp-5.0.1-py2.py3-none-any.whl (499 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 499.0/499.0 kB 4.7 MB/s eta 0:00:00
# Installing collected packages: spark-nlp
# Successfully installed spark-nlp-5.0.1
# Collecting pyspark
#   Downloading pyspark-3.4.1.tar.gz (310.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.8/310.8 MB 3.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.4.1-py2.py3-none-any.whl size=311285398 sha256=76cab1e5c3dc61f3ba59f22b8cb454c7271829d805e3218613f5544021d1e646
#   Stored in directory: /root/.cache/pip/wheels/0d/77/a3/ff2f74cc9ab41f8f594dabf0579c2a7c6de920d584206e0834
# Successfully built pyspark
# Installing collected packages: pyspark
# Successfully installed pyspark-3.4.1

# %%
from pyspark.sql import SparkSession, DataFrame

# %%
import sparknlp

# Start Spark Session
spark = sparknlp.start()

# %%
spark = SparkSession.builder.appName("sentimentanalysis").getOrCreate()

# %%
df = spark.read.option("multiLine", True).option("header", True).option("escape", "\"").csv("/content/Amazon_product_review.csv")

# %%
df.show(10)
df.printSchema()

# %%
  data = df.randomSplit([0.7,0.3])
  train_set = data[0]
  test_set = data[1]
  train_count = train_set.count()
  test_count = test_set.count()
  print(train_count)
  print(test_count)
# Out:
# 14036
# 5964

# %%
import sparknlp
from sparknlp.annotator import *
from sparknlp.common import *
from sparknlp.base import *
from pyspark.ml import Pipeline

documentAssembler = DocumentAssembler() \
    .setInputCol("short_review") \
    .setOutputCol("document")
sent_embeddings = BertSentenceEmbeddings.pretrained("sent_small_bert_L2_128") \
      .setInputCols("document") \
      .setOutputCol("sentence_embeddings")
classifierDl = ClassifierDLApproach()\
  .setInputCols(["sentence_embeddings"])\
  .setOutputCol("pred_label")\
  .setLabelColumn("Sentiment")\
  .setMaxEpochs(125)\
  .setLr(0.0007)
pipeline = Pipeline().setStages([
    documentAssembler,
    sent_embeddings,
    classifierDl
])
# Out:
# sent_small_bert_L2_128 download started this may take some time.
# Approximate size to download 16.1 MB
# [OK!]

# %%
model = pipeline.fit(train_set)

# %%
preds = model.transform(test_set)
preds.show()
# Out:
# +--------------------+---------+--------------------+--------------------+--------------------+
# |        short_review|Sentiment|            document| sentence_embeddings|          pred_label|
# +--------------------+---------+--------------------+--------------------+--------------------+
# |"Fast service, th...| positive|[{document, 0, 39...|[{sentence_embedd...|[{category, 0, 39...|
# |"Really impressed...| positive|[{document, 0, 36...|[{sentence_embedd...|[{category, 0, 36...|
# |"Super extended l...| negative|[{document, 0, 19...|[{sentence_embedd...|[{category, 0, 19...|
# |"The armband is g...| positive|[{document, 0, 35...|[{sentence_embedd...|[{category, 0, 35...|
# |&34;BUYER BEWARE ...| negative|[{document, 0, 35...|[{sentence_embedd...|[{category, 0, 35...|
# |&34;you get what ...| negative|[{document, 0, 25...|[{sentence_embedd...|[{category, 0, 25...|
# |*** UPDATE Novemb...| positive|[{document, 0, 10...|[{sentence_embedd...|[{category, 0, 10...|
# |***ORIGINAL REVIE...| positive|[{document, 0, 17...|[{sentence_embedd...|[{category, 0, 17...|
# |*Instructions are...| positive|[{document, 0, 24...|[{sentence_embedd...|[{category, 0, 24...|
# |+ Good sound qual...| positive|[{document, 0, 13...|[{sentence_embedd...|[{category, 0, 13...|
# |+Shipment Came Ea...| positive|[{document, 0, 28...|[{sentence_embedd...|[{category, 0, 28...|
# |- Much more refle...| positive|[{document, 0, 24...|[{sentence_embedd...|[{category, 0, 24...|
# |- There isn't any...| negative|[{document, 0, 36...|[{sentence_embedd...|[{category, 0, 36...|
# |-This was for my ...| positive|[{document, 0, 98...|[{sentence_embedd...|[{category, 0, 98...|
# |-Very difficult t...| negative|[{document, 0, 60...|[{sentence_embedd...|[{category, 0, 60...|
# |... only had this...| positive|[{document, 0, 11...|[{sentence_embedd...|[{category, 0, 11...|
# |... that give off...| positive|[{document, 0, 27...|[{sentence_embedd...|[{category, 0, 27...|
# |0-5A adjustable c...| positive|[{document, 0, 47...|[{sentence_embedd...|[{category, 0, 47...|
# |1 CABLE NEVER WOR...| negative|[{document, 0, 14...|[{sentence_embedd...|[{category, 0, 14...|
# |1 Star off due to...| positive|[{document, 0, 97...|[{sentence_embedd...|[{category, 0, 97...|
# +--------------------+---------+--------------------+--------------------+--------------------+
# only showing top 20 rows

# %%
df = preds.select(['Sentiment','pred_label.result']).toPandas()
df['result'] = df['result'].apply(lambda x: x[0])

# %%
df
# Out:
# DataFrame[short_review: string, Sentiment: string]

# %%
from sklearn.metrics import classification_report
print(classification_report(df['result'],df['Sentiment']))
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.48      0.66      0.56      1024
#     positive       0.92      0.85      0.89      4940
#
#     accuracy                           0.82      5964
#    macro avg       0.70      0.76      0.72      5964
# weighted avg       0.85      0.82      0.83      5964

# %% [markdown]
# #BERT in Spark

# %%
import sparknlp
from sparknlp.base import *
from sparknlp.annotator import *
from pyspark.ml import Pipeline

documentAssembler = DocumentAssembler() \
    .setInputCol("short_review") \
    .setOutputCol("document")
tokenizer = Tokenizer() \
    .setInputCols(["document"]) \
    .setOutputCol("token")
sequenceClassifier = BertForSequenceClassification.pretrained() \
    .setInputCols(["token", "document"]) \
    .setOutputCol("label") \
    .setCaseSensitive(True) \
    .setThreshold(0.5) \
    .setMaxSentenceLength(128) \
    .setBatchSize(32)
pipeline = Pipeline().setStages([
    documentAssembler,
    tokenizer,
    sequenceClassifier
])
# Out:
# bert_base_sequence_classifier_imdb download started this may take some time.
# Approximate size to download 387.6 MB
# [OK!]

# %%
model = pipeline.fit(train_set)

# %%
preds = model.transform(test_set)
preds.show()
# Out:
# +--------------------+---------+--------------------+--------------------+--------------------+
# |        short_review|Sentiment|            document|               token|               label|
# +--------------------+---------+--------------------+--------------------+--------------------+
# |"Fast service, th...| positive|[{document, 0, 39...|[{token, 0, 0, ",...|[{category, 0, 39...|
# |"Really impressed...| positive|[{document, 0, 36...|[{token, 0, 0, ",...|[{category, 0, 36...|
# |"Super extended l...| negative|[{document, 0, 19...|[{token, 0, 0, ",...|[{category, 0, 19...|
# |"The armband is g...| positive|[{document, 0, 35...|[{token, 0, 0, ",...|[{category, 0, 35...|
# |&34;BUYER BEWARE ...| negative|[{document, 0, 35...|[{token, 0, 8, &3...|[{category, 0, 35...|
# |&34;you get what ...| negative|[{document, 0, 25...|[{token, 0, 6, &3...|[{category, 0, 25...|
# |*** UPDATE Novemb...| positive|[{document, 0, 10...|[{token, 0, 2, **...|[{category, 0, 10...|
# |***ORIGINAL REVIE...| positive|[{document, 0, 17...|[{token, 0, 2, **...|[{category, 0, 17...|
# |*Instructions are...| positive|[{document, 0, 24...|[{token, 0, 0, *,...|[{category, 0, 24...|
# |+ Good sound qual...| positive|[{document, 0, 13...|[{token, 0, 0, +,...|[{category, 0, 13...|
# |+Shipment Came Ea...| positive|[{document, 0, 28...|[{token, 0, 8, +S...|[{category, 0, 28...|
# |- Much more refle...| positive|[{document, 0, 24...|[{token, 0, 0, -,...|[{category, 0, 24...|
# |- There isn't any...| negative|[{document, 0, 36...|[{token, 0, 0, -,...|[{category, 0, 36...|
# |-This was for my ...| positive|[{document, 0, 98...|[{token, 0, 0, -,...|[{category, 0, 98...|
# |-Very difficult t...| negative|[{document, 0, 60...|[{token, 0, 0, -,...|[{category, 0, 60...|
# |... only had this...| positive|[{document, 0, 11...|[{token, 0, 2, .....|[{category, 0, 11...|
# |... that give off...| positive|[{document, 0, 27...|[{token, 0, 2, .....|[{category, 0, 27...|
# |0-5A adjustable c...| positive|[{document, 0, 47...|[{token, 0, 3, 0-...|[{category, 0, 47...|
# |1 CABLE NEVER WOR...| negative|[{document, 0, 14...|[{token, 0, 0, 1,...|[{category, 0, 14...|
# |1 Star off due to...| positive|[{document, 0, 97...|[{token, 0, 0, 1,...|[{category, 0, 97...|
# +--------------------+---------+--------------------+--------------------+--------------------+
# only showing top 20 rows

# %%
df = preds.select(['Sentiment','label.result']).toPandas()
df['result'] = df['result'].apply(lambda x: x[0])

# %%
df['Sentiment'] = df['Sentiment'].str[:3]
df
# Out:
#      Sentiment result
# 0          pos    pos
# 1          pos    pos
# 2          neg    neg
# 3          pos    pos
# 4          neg    neg
# ...        ...    ...
# 5959       pos    neg
# 5960       neg    neg
# 5961       neg    neg
# 5962       neg    neg
# 5963       pos    pos
#
# [5964 rows x 2 columns]

# %%
from sklearn.metrics import classification_report
print(classification_report(df['result'],df['Sentiment']))
# Out:
#               precision    recall  f1-score   support
#
#          neg       0.91      0.58      0.71      2208
#          pos       0.80      0.97      0.87      3756
#
#     accuracy                           0.83      5964
#    macro avg       0.86      0.78      0.79      5964
# weighted avg       0.84      0.83      0.81      5964

# %%
model_path = "/content/Model"
model.write().overwrite().save(model_path)

print("Model saved successfully at:", model_path)
# Out:
# Model saved successfully at: /content/Model
